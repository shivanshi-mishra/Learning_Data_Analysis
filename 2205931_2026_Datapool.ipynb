# %% [markdown]
# <a href="https://colab.research.google.com/github/shivanshi-mishra/Learning_Data_Analysis/blob/main/2205931_2026_Datapool.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.exceptions import ConvergenceWarning

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter("ignore", category=ConvergenceWarning)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
df = pd.read_csv('/content/HR-Employee-Attrition.csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely       1102                   Sales                 1
# 1   49        No  Travel_Frequently        279  Research & Development                 8
# 2   37       Yes      Travel_Rarely       1373  Research & Development                 2
# 3   33        No  Travel_Frequently       1392  Research & Development                 3
# 4   27        No      Travel_Rarely        591  Research & Development                 2
#
#    Education EducationField  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0          2  Life Sciences              1               1                        2  Female
# 1          1  Life Sciences              1               2                        3    Male
# 2          2          Other              1               4                        4    Male
# 3          4  Life Sciences              1               5                        4  Female
# 4          1        Medical              1               7                        1    Male
#
#    HourlyRate  JobInvolvement  JobLevel                JobRole  JobSatisfaction MaritalStatus  \
# 0          94               3         2        Sales Executive                4        Single
# 1          61               2         2     Research Scientist                2       Married
# 2          92               2         1  Laboratory Technician                3        Single
# 3          56               3         1     Research Scientist                3       Married
# 4          40               3         1  Laboratory Technician                2       Married
#
#    MonthlyIncome  MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0           5993        19479                   8      Y      Yes                 11
# 1           5130        24907                   1      Y       No                 23
# 2           2090         2396                   6      Y      Yes                 15
# 3           2909        23159                   1      Y      Yes                 11
# 4           3468        16632                   9      Y       No                 12
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                  3                         1             80                 0
# 1                  4                         4             80                 1
# 2                  3                         2             80                 0
# 3                  3                         3             80                 0
# 4                  3                         4             80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                  8                      0                1               6                   4
# 1                 10                      3                3              10                   7
# 2                  7                      3                3               0                   0
# 3                  8                      3                3               8                   7
# 4                  6                      3                3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     5
# 1                        1                     7
# 2                        0                     0
# 3                        3                     0
# 4                        2                     2

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction',
#        'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
df.describe()
# Out:
#            Age  DailyRate  DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# count 1470.000   1470.000          1470.000   1470.000       1470.000        1470.000
# mean    36.924    802.486             9.193      2.913          1.000        1024.865
# std      9.135    403.509             8.107      1.024          0.000         602.024
# min     18.000    102.000             1.000      1.000          1.000           1.000
# 25%     30.000    465.000             2.000      2.000          1.000         491.250
# 50%     36.000    802.000             7.000      3.000          1.000        1020.500
# 75%     43.000   1157.000            14.000      4.000          1.000        1555.750
# max     60.000   1499.000            29.000      5.000          1.000        2068.000
#
#        EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  JobSatisfaction  \
# count                 1470.000    1470.000        1470.000  1470.000         1470.000
# mean                     2.722      65.891           2.730     2.064            2.729
# std                      1.093      20.329           0.712     1.107            1.103
# min                      1.000      30.000           1.000     1.000            1.000
# 25%                      2.000      48.000           2.000     1.000            2.000
# 50%                      3.000      66.000           3.000     2.000            3.000
# 75%                      4.000      83.750           3.000     3.000            4.000
# max                      4.000     100.000           4.000     5.000            4.000
#
#        MonthlyIncome  MonthlyRate  NumCompaniesWorked  PercentSalaryHike  PerformanceRating  \
# count       1470.000     1470.000            1470.000           1470.000           1470.000
# mean        6502.931    14313.103               2.693             15.210              3.154
# std         4707.957     7117.786               2.498              3.660              0.361
# min         1009.000     2094.000               0.000             11.000              3.000
# 25%         2911.000     8047.000               1.000             12.000              3.000
# 50%         4919.000    14235.500               2.000             14.000              3.000
# 75%         8379.000    20461.500               4.000             18.000              3.000
# max        19999.000    26999.000               9.000             25.000              4.000
#
#        RelationshipSatisfaction  StandardHours  StockOptionLevel  TotalWorkingYears  \
# count                  1470.000       1470.000          1470.000           1470.000
# mean                      2.712         80.000             0.794             11.280
# std                       1.081          0.000             0.852              7.781
# min                       1.000         80.000             0.000              0.000
# 25%                       2.000         80.000             0.000              6.000
# 50%                       3.000         80.000             1.000             10.000
# 75%                       4.000         80.000             1.000             15.000
# max                       4.000         80.000             3.000             40.000
#
#        TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count               1470.000         1470.000        1470.000            1470.000
# mean                   2.799            2.761           7.008               4.229
# std                    1.289            0.706           6.127               3.623
# min                    0.000            1.000           0.000               0.000
# 25%                    2.000            2.000           3.000               2.000
# 50%                    3.000            3.000           5.000               3.000
# 75%                    3.000            3.000           9.000               7.000
# max                    6.000            4.000          40.000              18.000
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count                 1470.000              1470.000
# mean                     2.188                 4.123
# std                      3.222                 3.568
# min                      0.000                 0.000
# 25%                      0.000                 2.000
# 50%                      1.000                 3.000
# 75%                      3.000                 7.000
# max                     15.000                17.000

# %%
df.drop_duplicates()
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely       1102                   Sales                 1
# 1   49        No  Travel_Frequently        279  Research & Development                 8
# 2   37       Yes      Travel_Rarely       1373  Research & Development                 2
# 3   33        No  Travel_Frequently       1392  Research & Development                 3
# 4   27        No      Travel_Rarely        591  Research & Development                 2
#
#    Education EducationField  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0          2  Life Sciences              1               1                        2  Female
# 1          1  Life Sciences              1               2                        3    Male
# 2          2          Other              1               4                        4    Male
# 3          4  Life Sciences              1               5                        4  Female
# 4          1        Medical              1               7                        1    Male
#
#    HourlyRate  JobInvolvement  JobLevel                JobRole  JobSatisfaction MaritalStatus  \
# 0          94               3         2        Sales Executive                4        Single
# 1          61               2         2     Research Scientist                2       Married
# 2          92               2         1  Laboratory Technician                3        Single
# 3          56               3         1     Research Scientist                3       Married
# 4          40               3         1  Laboratory Technician                2       Married
#
#    MonthlyIncome  MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0           5993        19479                   8      Y      Yes                 11
# 1           5130        24907                   1      Y       No                 23
# 2           2090         2396                   6      Y      Yes                 15
# 3           2909        23159                   1      Y      Yes                 11
# 4           3468        16632                   9      Y       No                 12
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                  3                         1             80                 0
# 1                  4                         4             80                 1
# 2                  3                         2             80                 0
# 3                  3                         3             80                 0
# 4                  3                         4             80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                  8                      0                1               6                   4
# 1                 10                      3                3              10                   7
# 2                  7                      3                3               0                   0
# 3                  8                      3                3               8                   7
# 4                  6                      3                3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     5
# 1                        1                     7
# 2                        0                     0
# 3                        3                     0
# 4                        2                     2

# %%
df_new = df[['Age',
             'OverTime',
             'MaritalStatus',
             'JobRole',
             'Gender',
             'EducationField',
             'Department',
             'BusinessTravel',
             'Education',
             'DistanceFromHome',
             'DailyRate',
             'Attrition']]

# %%
df_new.head()
# Out:
#    Age OverTime MaritalStatus                JobRole  Gender EducationField  \
# 0   41      Yes        Single        Sales Executive  Female  Life Sciences
# 1   49       No       Married     Research Scientist    Male  Life Sciences
# 2   37      Yes        Single  Laboratory Technician    Male          Other
# 3   33      Yes       Married     Research Scientist  Female  Life Sciences
# 4   27       No       Married  Laboratory Technician    Male        Medical
#
#                Department     BusinessTravel  Education  DistanceFromHome  DailyRate Attrition
# 0                   Sales      Travel_Rarely          2                 1       1102       Yes
# 1  Research & Development  Travel_Frequently          1                 8        279        No
# 2  Research & Development      Travel_Rarely          2                 2       1373       Yes
# 3  Research & Development  Travel_Frequently          4                 3       1392        No
# 4  Research & Development      Travel_Rarely          1                 2        591        No

# %%
df_new.isnull().sum()
# Out:
# Age                 0
# OverTime            0
# MaritalStatus       0
# JobRole             0
# Gender              0
# EducationField      0
# Department          0
# BusinessTravel      0
# Education           0
# DistanceFromHome    0
# DailyRate           0
# Attrition           0
# dtype: int64

# %%
kpi1 = df_new[(df_new['Department'] == 'Sales') & (df_new['EducationField'] == 'Marketing')]
kpi1.head(10)
# Out:
#     Age OverTime MaritalStatus               JobRole  Gender EducationField Department  \
# 27   42       No       Married       Sales Executive    Male      Marketing      Sales
# 29   46       No        Single               Manager  Female      Marketing      Sales
# 36   50      Yes       Married  Sales Representative    Male      Marketing      Sales
# 37   35       No       Married  Sales Representative  Female      Marketing      Sales
# 46   34       No        Single       Sales Executive    Male      Marketing      Sales
# 48   46      Yes        Single       Sales Executive    Male      Marketing      Sales
# 52   44      Yes      Divorced       Sales Executive  Female      Marketing      Sales
# 54   26      Yes       Married       Sales Executive  Female      Marketing      Sales
# 76   35       No        Single       Sales Executive    Male      Marketing      Sales
# 91   51      Yes        Single       Sales Executive    Male      Marketing      Sales
#
#        BusinessTravel  Education  DistanceFromHome  DailyRate Attrition
# 27      Travel_Rarely          4                 8        691        No
# 29      Travel_Rarely          4                 2        705        No
# 36      Travel_Rarely          2                 3        869       Yes
# 37      Travel_Rarely          3                 2        890        No
# 46         Non-Travel          4                23       1065        No
# 48  Travel_Frequently          4                 5       1211        No
# 52      Travel_Rarely          5                 1       1488        No
# 54      Travel_Rarely          3                23       1443        No
# 76      Travel_Rarely          4                 1        776        No
# 91      Travel_Rarely          4                21        632        No

# %%
df_new['BusinessTravel'].value_counts()
# Out:
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64

# %%
df_new.groupby('BusinessTravel')['DailyRate'].mean()
# Out:
# BusinessTravel
# Non-Travel          816.960
# Travel_Frequently   792.628
# Travel_Rarely       803.022
# Name: DailyRate, dtype: float64

# %%
kpi3 = df_new.groupby('Department')['OverTime'].count()
kpi3.head()
# Out:
# Department
# Human Resources            63
# Research & Development    961
# Sales                     446
# Name: OverTime, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=kpi3.index, y=kpi3.values, palette ='viridis')
plt.title('Department Wise OverTime Count')
plt.xlabel('Department')
plt.ylabel('Count')
plt.show()

# %%
JobRole_count = df_new['JobRole'].value_counts()

# %%
plt.figure(figsize = (12,8))
JobRole_count.plot(kind = 'pie',
                   autopct = '%1.0f%%',
                   explode = [0.15]*len(JobRole_count),
                  shadow = True,
                  startangle=100)
plt.show();

# %%
sales_female = df_new[(df_new['JobRole'] =='Manager') & (df_new['Gender'] == 'Female')]
sales_female.head()
# Out:
#      Age OverTime MaritalStatus  JobRole  Gender   EducationField              Department  \
# 18    53       No       Married  Manager  Female    Life Sciences                   Sales
# 25    53       No      Divorced  Manager  Female            Other  Research & Development
# 29    46       No        Single  Manager  Female        Marketing                   Sales
# 65    55      Yes      Divorced  Manager  Female          Medical  Research & Development
# 105   59       No       Married  Manager  Female  Human Resources         Human Resources
#
#     BusinessTravel  Education  DistanceFromHome  DailyRate Attrition
# 18   Travel_Rarely          4                 2       1219        No
# 25   Travel_Rarely          3                 5       1282        No
# 29   Travel_Rarely          4                 2        705        No
# 65   Travel_Rarely          3                 8        836        No
# 105     Non-Travel          4                 2       1420        No

# %%
female  = df_new[df_new['Gender']=='Female']
female.head()
# Out:
#     Age OverTime MaritalStatus                 JobRole  Gender EducationField  \
# 0    41      Yes        Single         Sales Executive  Female  Life Sciences
# 3    33      Yes       Married      Research Scientist  Female  Life Sciences
# 6    59      Yes       Married   Laboratory Technician  Female        Medical
# 11   29      Yes        Single   Laboratory Technician  Female  Life Sciences
# 15   29       No      Divorced  Manufacturing Director  Female  Life Sciences
#
#                 Department     BusinessTravel  Education  DistanceFromHome  DailyRate Attrition
# 0                    Sales      Travel_Rarely          2                 1       1102       Yes
# 3   Research & Development  Travel_Frequently          4                 3       1392        No
# 6   Research & Development      Travel_Rarely          3                 3       1324        No
# 11  Research & Development      Travel_Rarely          2                15        153        No
# 15  Research & Development      Travel_Rarely          4                21       1389        No

# %%
female.groupby('EducationField').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
female_unmarried = female[female['MaritalStatus']!='Married']
female_unmarried.head()
# Out:
#     Age OverTime MaritalStatus                 JobRole  Gender EducationField  \
# 0    41      Yes        Single         Sales Executive  Female  Life Sciences
# 11   29      Yes        Single   Laboratory Technician  Female  Life Sciences
# 15   29       No      Divorced  Manufacturing Director  Female  Life Sciences
# 20   24       No      Divorced  Manufacturing Director  Female          Other
# 22   34       No        Single       Research Director  Female  Life Sciences
#
#                 Department BusinessTravel  Education  DistanceFromHome  DailyRate Attrition
# 0                    Sales  Travel_Rarely          2                 1       1102       Yes
# 11  Research & Development  Travel_Rarely          2                15        153        No
# 15  Research & Development  Travel_Rarely          4                21       1389        No
# 20  Research & Development     Non-Travel          2                11        673        No
# 22  Research & Development  Travel_Rarely          4                 7        419        No

# %%
kpi4 = female_unmarried['Department'].value_counts()
kpi4
# Out:
# Department
# Research & Development    212
# Sales                      95
# Human Resources             9
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=kpi4.index, y=kpi4.values, palette ='husl')
plt.title('Unmarried Women in the Departments')
plt.xlabel('Department')
plt.ylabel('Count')
plt.show();

# %%
kpi5 = female_unmarried['EducationField'].value_counts()
kpi5
# Out:
# EducationField
# Life Sciences       132
# Medical             108
# Marketing            31
# Technical Degree     30
# Other                12
# Human Resources       3
# Name: count, dtype: int64

# %%
plt.figure(figsize = (12,8))
sns.barplot(x=kpi5.index, y= kpi5.values, palette = 'viridis')
plt.title('Unmarried Women in the Education Fields')
plt.xlabel('Department')
plt.ylabel('Count')
plt.show();

# %%
plt.figure(figsize = (12,8))
kpi5.plot(kind = 'pie',
                   autopct = '%1.0f%%',
                   explode = [0.05]*len(kpi5),
                  shadow = True,
                  startangle=150)
plt.show();

# %%
kpi6 = df_new.groupby(['Gender','Department','JobRole']).agg({'Age':'mean'}).reset_index()
kpi6.head()
# Out:
#    Gender              Department                    JobRole    Age
# 0  Female         Human Resources            Human Resources 34.438
# 1  Female         Human Resources                    Manager 50.500
# 2  Female  Research & Development  Healthcare Representative 38.902
# 3  Female  Research & Development      Laboratory Technician 35.271
# 4  Female  Research & Development                    Manager 47.500

# %%
kpi7 = df_new['MaritalStatus'].value_counts()
kpi7
# Out:
# MaritalStatus
# Married     673
# Single      470
# Divorced    327
# Name: count, dtype: int64

# %%
plt.figure(figsize = (10,6))
kpi7.plot(kind = 'pie',
                   autopct = '%1.0f%%',
                   explode = [0.05]*len(kpi7),
                  shadow = True,
                  startangle=150)
plt.show();

# %%
kpi8 = df_new['Attrition'].value_counts()
kpi8
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
plt.figure(figsize = (12,8))
sns.barplot(x=kpi8.index, y= kpi8.values, palette = 'viridis')
plt.show();

# %%
male  = df_new[df_new['Gender']=='Male']
male.head()
# Out:
#    Age OverTime MaritalStatus                JobRole Gender EducationField  \
# 1   49       No       Married     Research Scientist   Male  Life Sciences
# 2   37      Yes        Single  Laboratory Technician   Male          Other
# 4   27       No       Married  Laboratory Technician   Male        Medical
# 5   32       No        Single  Laboratory Technician   Male  Life Sciences
# 7   30       No      Divorced  Laboratory Technician   Male  Life Sciences
#
#                Department     BusinessTravel  Education  DistanceFromHome  DailyRate Attrition
# 1  Research & Development  Travel_Frequently          1                 8        279        No
# 2  Research & Development      Travel_Rarely          2                 2       1373       Yes
# 4  Research & Development      Travel_Rarely          1                 2        591        No
# 5  Research & Development  Travel_Frequently          2                 2       1005        No
# 7  Research & Development      Travel_Rarely          1                24       1358        No

# %%
male.groupby('EducationField').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
plt.figure(figsize = (12,8))
sns.barplot(x=kpi9.index, y= kpi9.values, palette = 'husl')
plt.show();

# %%
male_unmarried = male[male['MaritalStatus']!='Married']
male_unmarried.head()
# Out:
#     Age OverTime MaritalStatus                 JobRole Gender EducationField  \
# 2    37      Yes        Single   Laboratory Technician   Male          Other
# 5    32       No        Single   Laboratory Technician   Male  Life Sciences
# 7    30       No      Divorced   Laboratory Technician   Male  Life Sciences
# 8    38       No        Single  Manufacturing Director   Male  Life Sciences
# 12   31       No      Divorced      Research Scientist   Male  Life Sciences
#
#                 Department     BusinessTravel  Education  DistanceFromHome  DailyRate Attrition
# 2   Research & Development      Travel_Rarely          2                 2       1373       Yes
# 5   Research & Development  Travel_Frequently          2                 2       1005        No
# 7   Research & Development      Travel_Rarely          1                24       1358        No
# 8   Research & Development  Travel_Frequently          3                23        216        No
# 12  Research & Development      Travel_Rarely          1                26        670        No

# %%
kpi9 = female_unmarried['Department'].value_counts()
kpi9
# Out:
# Department
# Research & Development    212
# Sales                      95
# Human Resources             9
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=kpi9.index, y=kpi9.values, palette ='husl')
plt.title('Unmarried Men in the Departments')
plt.xlabel('Department')
plt.ylabel('Count')
plt.show();

# %%
kpi10 = male_unmarried['EducationField'].value_counts()
kpi10
# Out:
# EducationField
# Life Sciences       203
# Medical             146
# Marketing            51
# Technical Degree     41
# Other                34
# Human Resources       6
# Name: count, dtype: int64

# %%
plt.figure(figsize = (12,8))
sns.barplot(x=kpi10.index, y= kpi10.values, palette = 'viridis')
plt.title('Unmarried Men in the Education Fields')
plt.xlabel('Department')
plt.ylabel('Count')
plt.show();

# %%
plt.figure(figsize = (12,8))
kpi10.plot(kind = 'pie',
                   autopct = '%1.0f%%',
                   explode = [0.05]*len(kpi5),
                  shadow = True,
                  startangle=150)
plt.show();
